# %%
import pandas as pd
import numpy as np 
from numpy import array
import matplotlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from numpy import array
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import TimeDistributed
from keras.layers import Dense, LSTM, Dropout, GRU
from keras.layers import Flatten
#from keras.layers.convolutional import Conv1D
from keras.layers import Conv1D
from keras.layers import ConvLSTM2D
from keras.layers import MaxPooling1D
from sklearn.model_selection import train_test_split
import statistics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.ar_model import AutoReg
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from math import sqrt
import time
from sklearn.preprocessing import MinMaxScaler
import math
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=100)
#es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
columns = ['steps']
df = pd.read_csv('/Users/fatemeh/Thises/exprimentalResult/ActivityClassification/PMData_Analysis/Classification/2/PMData_features_vector.csv')

df = df[columns]
test_set = df
df.head()
# Out:
#      steps
# 0  17873.0
# 1  13118.0
# 2  14312.0
# 3  10970.0
# 4  16186.0

# %%
df.isna().sum()
# Out:
# steps    0
# dtype: int64

# %%
training_set = df.values
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
x_train = []
y_train = []

# %%
train_size = int(len(training_set) * 0.8)
timestamp = len(training_set) - train_size

print (train_size, timestamp)
# Out:
# 1800 450

# %%
length = len(training_set)
for i in range(timestamp, length):
    x_train.append(training_set_scaled[i-timestamp:i, 0])
    y_train.append(training_set_scaled[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
n_steps = x_train.shape[1]
x_train = np.reshape(x_train, (x_train.shape[0], n_steps, 1))
n_features = 1
n_steps
# Out:
# 450

# %%
def build_stacked_LSTM(n_steps, n_features):
    # define model
    model = Sequential()
    model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
    model.add(LSTM(100, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse', metrics=['acc'])
    return model


def mse_test(X, y, model, split = 0.2):
	X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = split)
	history = model.fit(X_train, y_train, epochs=500, batch_size=50, validation_data=(X_test, y_test), verbose= 2, shuffle=False)
	loss = (statistics.mean(history.history['loss']))
	val_loss = (statistics.mean(history.history['val_loss']))    
	
	# summarize history for loss
	pyplot.plot(history.history['loss'])
	pyplot.plot(history.history['val_loss'])
	pyplot.title('Model loss')
	pyplot.ylabel('Loss')
	pyplot.xlabel('Epoch')
	pyplot.legend(['Train', 'Test'], loc='upper left')
	pyplot.show()
    
	return loss, val_loss

# %%
bidi_model = build_stacked_LSTM(n_steps, n_features)

print(bidi_model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 450, 100)       │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121,301 (473.83 KB)
#  Trainable params: 121,301 (473.83 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# fit model
history = bidi_model.fit(x_train, y_train, epochs = 200, batch_size = 50, validation_split = 0.05, callbacks = [rlrop])
# Out:
# Epoch 1/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 256ms/step - acc: 0.0076 - loss: 0.0322 - val_acc: 0.0000e+00 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 2/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 243ms/step - acc: 0.0076 - loss: 0.0185 - val_acc: 0.0000e+00 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 3/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - acc: 0.0076 - loss: 0.0188 - val_acc: 0.0000e+00 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 4/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step - acc: 0.0076 - loss: 0.0178 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 5/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - acc: 0.0076 - loss: 0.0177 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 6/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 247ms/step - acc: 0.0076 - loss: 0.0173 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 7/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - acc: 0.0076 - loss: 0.0171 - val_acc: 0.0000e+00 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 8/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - acc: 0.0076 - loss: 0.0173 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 9/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - acc: 0.0076 - loss: 0.0170 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 10/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/
- val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 99/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 100/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 327ms/step - acc: 0.0076 - loss: 0.0157 - val_acc: 0.0000e+00 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 101/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 102/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 103/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - acc: 0.0076 - loss: 0.0159 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 104/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - acc: 0.0076 - loss: 0.0157 - val_acc: 0.0000e+00 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 105/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 106/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - acc: 0.0076 - loss: 0.0157 - val_acc: 0.0000e+00 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 107/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 108/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 109/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 110/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 111/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 112/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - acc: 0.0076 - loss: 0.0158 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 113/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - acc: 0.0076 - loss: 0.0157 - val_acc: 0.0000e+00 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 114/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 115/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0157 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 116/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 117/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - acc: 0.0076 - loss: 0.0154 - val_acc: 0.0000e+00 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 118/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 301ms/step - acc: 0.0076 - loss: 0.0154 - val_acc: 0.0000e+00 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 119/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - acc: 0.0076 - loss: 0.0155 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 120/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0154 - val_acc: 0.0000e+00 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 121/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 301ms/step - acc: 0.0076 - loss: 0.0155 - val_acc: 0.0000e+00 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 122/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - acc: 0.0076 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 123/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0155 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 124/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 319ms/step - acc: 0.0076 - loss: 0.0153 - val_acc: 0.0000e+00 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 125/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - acc: 0.0076 - loss: 0.0155 - val_acc: 0.0000e+00 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 126/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - acc: 0.0076 - loss: 0.0153 - val_acc: 0.0000e+00 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 127/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - acc: 0.0076 - loss: 0.0153 - val_acc: 0.0000e+00 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 128/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - acc: 0.0076 - loss: 0.0154 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 129/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - acc: 0.0076 - loss: 0.0149 - val_acc: 0.0000e+00 - val_loss: 0.0020 - learning_rate: 1.0000e-04
# Epoch 130/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 301ms/step - acc: 0.0076 - loss: 0.0149 - val_acc: 0.0000e+00 - val_loss: 0.0019 - learning_rate: 1.0000e-04
# Epoch 131/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 132/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 133/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 134/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 135/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 136/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 137/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 138/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - acc: 0.0076 - loss: 0.0148 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 139/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0019 - learning_rate: 1.0000e-04
# Epoch 140/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 141/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 142/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 143/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 286ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 144/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 145/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 146/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 147/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 148/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 149/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 150/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0021 - learning_rate: 1.0000e-04
# Epoch 151/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 152/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 286ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0020 - learning_rate: 1.0000e-04
# Epoch 153/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 154/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 155/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 156/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 157/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 158/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 159/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - acc: 0.0076 - loss: 0.0147 - val_acc: 0.0000e+00 - val_loss: 0.0030 - learning_rate: 1.0000e-04
# Epoch 160/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 161/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 162/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 305ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 163/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 332ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 164/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 165/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 166/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 329ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 167/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 168/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 169/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 170/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 171/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 300ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 172/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 308ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 173/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 174/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 309ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 175/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 176/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 177/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 306ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 178/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 179/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 309ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 180/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 306ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 181/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 182/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - acc: 0.0076 - loss: 0.0146 - val_acc: 0.0000e+00 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 183/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 184/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 307ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 185/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 186/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 187/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 188/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 308ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0031 - learning_rate: 1.0000e-04
# Epoch 189/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 309ms/step - acc: 0.0076 - loss: 0.0145 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 190/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 191/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 192/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 316ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 193/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04
# Epoch 194/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 195/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 306ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0024 - learning_rate: 1.0000e-04
# Epoch 196/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0025 - learning_rate: 1.0000e-04
# Epoch 197/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 198/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 327ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0027 - learning_rate: 1.0000e-04
# Epoch 199/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - acc: 0.0076 - loss: 0.0144 - val_acc: 0.0000e+00 - val_loss: 0.0028 - learning_rate: 1.0000e-04
# Epoch 200/200
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 311ms/step - acc: 0.0076 - loss: 0.0143 - val_acc: 0.0000e+00 - val_loss: 0.0026 - learning_rate: 1.0000e-04

# %%
# Loss History

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Model Loss for PMData with stacked_LSTM')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.legend(['Train', 'Test'], loc='upper right')
pyplot.savefig('Pmdata_stacked_LSTM.png', dpi=300)
pyplot.show()

# %%
y_test = test_set.iloc[timestamp:].values

cases = (test_set.values).reshape(-1, 1)
cases_scaled = sc.transform(cases)

# %%
# the model will predict the values on x_test
x_test = [] 
length = len(test_set)

for i in range(timestamp, length):
    x_test.append(cases_scaled[i-timestamp:i, 0])
    
x_test = np.array(x_test)
print (x_test.shape)
x_test = np.reshape(x_test, (x_test.shape[0], n_steps, 1))
# Out:
# (1800, 450)

# %%
def RSE(y_true, y_predicted):
    """
    - y_true: Actual values
    - y_predicted: Predicted values
    """
    y_true = np.array(y_true)
    y_predicted = np.array(y_predicted)
    RSS = np.sum(np.square(y_true - y_predicted))

    rse = math.sqrt(RSS / (len(y_true) - 2))
    return rse

# %%
start = time.time()
y_pred = bidi_model.predict(x_test)
print(y_pred)
print ('compilation time : ', (time.time() - start)*1000.0)

predicted_value = sc.inverse_transform(y_pred)
print(predicted_value)

# calculate Metric
mae = mean_absolute_error(predicted_value, y_test)
mse = mean_squared_error(predicted_value, y_test)
rmse = sqrt(mean_squared_error(predicted_value, y_test))
forecast_error = np.mean(np.subtract(predicted_value, y_test))
#https://www.investopedia.com/terms/r/residual-standard-deviation.asp
rsd = RSE(y_test, predicted_value)

#r2_value = r2_score(predicted_value, y_test,multioutput='variance_weighted')
r2_value = r2_score(predicted_value, y_test)
print('Test MAE: %.3f' % mae)
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
print('Test FE: %.3f' % forecast_error)
print('Test R2: %.3f' % r2_value)
print('Test RSD: %.3f' % rsd)

#print (predicted_value)

# plotting the results
fig, ax = pyplot.subplots()
pyplot.plot(y_test, color = 'blue', label = 'Actual Total Step(s)')
pyplot.plot(predicted_value, color = 'red', label = 'Predicted Total Step(s)')
#plt.title('Case Prediction - mul_layer_3 Model')
#plt.xlabel('Time')
#plt.ylabel('Total Case(s)')
ax.set_xlabel('Days')
ax.set_ylabel('Total Step(s)')
ax.set_title('Step Prediction for PMData with stacked_LSTM')
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
pyplot.legend(loc='upper right')
pyplot.savefig('PMData_stack_LSTM.png', dpi=300)
pyplot.show()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step
# [[0.12981838]
#  [0.0792938 ]
#  [0.09101783]
#  ...
#  [0.03167401]
#  [0.09779389]
#  [0.04747624]]
# compilation time :  3219.123125076294
# [[5171.315 ]
#  [3158.6687]
#  [3625.695 ]
#  ...
#  [1261.7341]
#  [3895.6196]
#  [1891.2162]]
# Test MAE: 3461.555
# Test MSE: 21737073.687
# Test RMSE: 4662.303
# Test FE: 53.635
# Test R2: -0.004
# Test RSD: 4664.896

# %%
start = time.time()
#print(y_pred)

# load data
steps = df['steps'].values
#steps = df['Steps'].values
series=pd.Series(steps)

#AutoCorrelation Function
plot_acf(series)
pyplot.show()

#Partial autocorrelation function
#plot_pacf(series, lags=50)
plot_pacf(series, lags=14)
pyplot.show()

# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']

# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.8)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# persistence model on training set
train_pred = [x for x in train_X]

# calculate residuals
train_resid = [train_y[i]-train_pred[i] for i in range(len(train_pred))]

# model the training set residuals
window = 5
model = AutoReg(train_resid, lags=5)
model_fit = model.fit()
coef = model_fit.params

# walk forward over time steps in test
history = train_resid[len(train_resid)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()

for t in range(len(test_y)):
	# persistence
	yhat = test_X[t]
	error = test_y[t] - yhat
    
	# predict error
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	pred_error = coef[0]
	for d in range(window):
		pred_error += coef[d+1] * lag[window-d-1]
        
	# correct the prediction
	yhat = yhat + pred_error
	predictions.append(yhat)
	history.append(error)
	print('predicted=%f, expected=%f' % (yhat, test_y[t]))

#RSD
rsd = RSE(y_test, predicted_value)
print('Test RSD: %.3f' % rsd)
# error
rmse = sqrt(mean_squared_error(test_y, predictions))
print('Test RMSE: %.3f' % rmse)

forecast_error = np.mean(np.subtract(predicted_value, y_test))
print('Test fe: %.3f' % forecast_error)

r2_value = r2_score(predicted_value, y_test)
print('Test r2: %.3f' % r2_value)

# plot predicted error
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')
pyplot.title('Residual Error Minimization for P-01 in PMData')
pyplot.ylabel('Total steps')
pyplot.xlabel('Days')
pyplot.legend(['Expected', 'Predicted'], loc='upper right')
pyplot.savefig('AR_REM_PMData_01.png', dpi=300)
pyplot.show()

print ('compilation time : ', (time.time() - start)*1000.0)
# Out:
# predicted=10949.733204, expected=867.000000
# predicted=8029.428361, expected=867.000000
# predicted=6114.827860, expected=867.000000
# predicted=4698.117924, expected=867.000000
# predicted=3464.981989, expected=867.000000
# predicted=1929.142205, expected=93.000000
# predicted=632.992952, expected=93.000000
# predicted=13399.741130, expected=13087.000000
# predicted=13460.388589, expected=17005.000000
# predicted=14157.805065, expected=19254.000000
# predicted=15878.734955, expected=10129.000000
# predicted=13609.035111, expected=14586.000000
# predicted=14494.556043, expected=15215.000000
# predicted=14691.533688, expected=12037.000000
# predicted=14328.458001, expected=12250.000000
# predicted=13814.677420, expected=12368.000000
# predicted=12458.845042, expected=16326.000000
# predicted=14156.723023, expected=16302.000000
# predicted=14732.738662, expected=17495.000000
# predicted=15103.871377, expected=13214.000000
# predicted=14530.577365, expected=15784.000000
# predicted=15050.672502, expected=17029.000000
# predicted=16148.222304, expected=9556.000000
# predicted=14134.191389, expected=15059.000000
# predicted=14563.400427, expected=4348.000000
# predicted=11110.795274, expected=14919.000000
# predicted=12678.652398, expected=13852.000000
# predicted=13043.252333, expected=13446.000000
# predicted=12224.810677, expected=14044.000000
# predicted=13193.096223, expected=19953.000000
# predicted=14168.828871, expected=6658.000000
# predicted=13026.320799, expected=14382.000000
# predicted=13409.015325, expected=17397.000000
# predicted=14689.740768, expected=15571.000000
# predicted=14969.014135, expected=14774.000000
# predicted=15278.531055, expected=20054.000000
# predicted=15340.218279, expected=14646.000000
# predicted=16030.276183, expected=19967.000000
# predicted=17512.794993, expected=13130.000000
# predicted=15971.110093, expected=11479.000000
# predicted=14668.043767, expected=17773.000000
# predicted=16265.899227, expected=11439.000000
# predicted=14237.386863, expected=17036.000000
# predicted=15547.564591, expected=18784.000000
# predicted=15689.086398, expected=15142.000000
# predicted=15328.373569, expected=10536.000000
# predicted=14516.051056, expected=12410.000000
# predicted=13407.740561, expected=10310.000000
# predicted=13251.884387, expected=21591.000000
# predicted=15891.582062, expected=30146.000000
# predicted=19467.549403, expected=11091.000000
# predicted=16068.381874, expected=10180.000000
# predicted=14606.708996, expected=7829.000000
# predicted=12953.602096, expected=9485.000000
# predicted=13544.354328, expected=15572.000000
# predicted=14795.318553, expected=15689.000000
# predicted=12662.667185, expected=17184.000000
# predicted=13721.700856, expected=19207.000000
# predicted=15068.019258, expected=6769.000000
# predicted=12834.016168, expected=12205.000000
# predicted=13540.402964, expected=12505.000000
# predicted=13434.586625, expected=16445.000000
# predicted=14472.701555, expected=13140.000000
# predicted=13963.469389, expected=15865.000000
# predicted=13151.510052, expected=8490.000000
# predicted=12410.279333, expected=9364.000000
# predicted=11699.690347, expected=8809.000000
# predicted=11363.657981, expected=5877.000000
# predicted=9404.445555, expected=10294.000000
# predicted=9903.195024, expected=4076.000000
# predicted=7293.441219, expected=8976.000000
# predicted=7915.716332, expected=6581.000000
# predicted=7420.163371, expected=13796.000000
# predicted=9030.850130, expected=5241.000000
# predicted=8194.644046, expected=9841.000000
# predicted=8062.000684, expected=3062.000000
# predicted=7168.880550, expected=1472.000000
# predicted=5381.642637, expected=610.000000
# predicted=4787.600021, expected=2177.000000
# predicted=3164.647499, expected=1690.000000
# predicted=3122.829761, expected=597.000000
