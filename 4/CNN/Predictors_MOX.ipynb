# %%
import pandas as pd
import numpy as np 
from numpy import array
import matplotlib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from numpy import array
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import TimeDistributed
from keras.layers import Dense, LSTM, Dropout, GRU
from keras.layers import Flatten
#from keras.layers.convolutional import Conv1D
from keras.layers import Conv1D
from keras.layers import ConvLSTM2D
from keras.layers import MaxPooling1D
from sklearn.model_selection import train_test_split
import statistics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from statsmodels.tsa.ar_model import AutoReg
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from math import sqrt
import time
from sklearn.preprocessing import MinMaxScaler
import math
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=100)
#es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
columns = ['steps']
df = pd.read_csv('/Users/fatemeh/Thises/exprimentalResult/ActivityClassification/PMData_Analysis/Classification/3/MOX2_5_data_labelled.csv')

df = df[columns]
test_set = df
df.head()
# Out:
#    steps
# 0   9876
# 1  10074
# 2  11014
# 3   7656
# 4  12114

# %%
df.isna().sum()
# Out:
# steps    0
# dtype: int64

# %%
training_set = df.values
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
x_train = []
y_train = []

# %%
train_size = int(len(training_set) * 0.8)
timestamp = len(training_set) - train_size

print (train_size, timestamp)
# Out:
# 431 108

# %%
length = len(training_set)
for i in range(timestamp, length):
    x_train.append(training_set_scaled[i-timestamp:i, 0])
    y_train.append(training_set_scaled[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
n_steps = x_train.shape[1]
x_train = np.reshape(x_train, (x_train.shape[0], n_steps, 1))
n_features = 1
n_steps
# Out:
# 108

# %%
def cnn_1d(n_steps, n_features):    
    model = Sequential()
    model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(n_steps, n_features)))
    model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
    #model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    #model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    #model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D())
    #model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer = 'adam', loss = 'mse', metrics=['acc'])
    return model


def mse_test(X, y, model, split = 0.2):
	X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = split)
	history = model.fit(X_train, y_train, epochs=500, batch_size=50, validation_data=(X_test, y_test), verbose= 2, shuffle=False)
	loss = (statistics.mean(history.history['loss']))
	val_loss = (statistics.mean(history.history['val_loss']))    
	
	# summarize history for loss
	pyplot.plot(history.history['loss'])
	pyplot.plot(history.history['val_loss'])
	pyplot.title('Model loss')
	pyplot.ylabel('Loss')
	pyplot.xlabel('Epoch')
	pyplot.legend(['Train', 'Test'], loc='upper left')
	pyplot.show()
    
	return loss, val_loss

# %%
cnn_1d = cnn_1d(n_steps, n_features)

print(cnn_1d.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 106, 256)       │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 104, 256)       │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 52, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 13312)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        13,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 211,201 (825.00 KB)
#  Trainable params: 211,201 (825.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# fit model
history = cnn_1d.fit(x_train, y_train, epochs = 200, batch_size = 50, validation_split = 0.05, callbacks = [rlrop])
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - acc: 0.0024 - loss: 0.0346 - val_acc: 0.0000e+00 - val_loss: 0.0153 - learning_rate: 0.0010
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0024 - loss: 0.0201 - val_acc: 0.0000e+00 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0024 - loss: 0.0183 - val_acc: 0.0000e+00 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0167 - val_acc: 0.0000e+00 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0165 - val_acc: 0.0000e+00 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0024 - loss: 0.0156 - val_acc: 0.0000e+00 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0161 - val_acc: 0.0000e+00 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0155 - val_acc: 0.0000e+00 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0132 - val_acc: 0.0000e+00 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0128 - val_acc: 0.0000e+00 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0124 - val_acc: 0.0000e+00 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0112 - val_acc: 0.0000e+00 - val_loss: 0.0098 - learning_rate: 0.0010
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0024 - loss: 0.0108 - val_acc: 0.0000e+00 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0024 - loss: 0.0107 - val_acc: 0.0000e+00 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0101 - val_acc: 0.0000e+00 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0093 - val_acc: 0.0000e+00 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0087 - val_acc: 0.0000e+00 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0024 - loss: 0.0083 - val_acc: 0.0000e+00 - val_loss: 0.0120 - learning_rate: 0.0010
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0081 - val_acc: 0.0000e+00 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0075 - val_acc: 0.0000e+00 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0070 - val_acc: 0.0000e+00 - val_loss: 0.0113 - learning_rate: 0.0010
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0070 - val_acc: 0.0000e+00 - val_loss: 0.0124 - learning_rate: 0.0010
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0076 - val_acc: 0.0000e+00 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0064 - val_acc: 0.0000e+00 - val_loss: 0.0118 - learning_rate: 0.0010
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0058 - val_acc: 0.0000e+00 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0054 - val_acc: 0.0000e+00 - val_loss: 0.0126 - learning_rate: 0.0010
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0052 - val_acc: 0.0000e+00 - val_loss: 0.0127 - learning_rate: 0.0010
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0050 - val_acc: 0.0000e+00 - val_loss: 0.0128 - learning_rate: 0.0010
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - acc: 0.0049 - loss: 0.0047 - val_acc: 0.0000e+00 - val_loss: 0.0141 - learning_rate: 0.0010
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0046 - val_acc: 0.0000e+00 - val_loss: 0.0146 - learning_rate: 0.0010
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0040 - val_acc: 0.0000e+00 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0050 - val_acc: 0.0000e+00 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0040 - val_acc: 0.0000e+00 - val_loss: 0.0147 - learning_rate: 0.0010
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0036 - val_acc: 0.0000e+00 - val_loss: 0.0151 - learning_rate: 0.0010
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0032 - val_acc: 0.0000e+00 - val_loss: 0.0161 - learning_rate: 0.0010
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0033 - val_acc: 0.0000e+00 - val_loss: 0.0182 - learning_rate: 0.0010
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0044 - val_acc: 0.0000e+00 - val_loss: 0.0201 - learning_rate: 0.0010
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0045 - val_acc: 0.0000e+00 - val_loss: 0.0156 - learning_rate: 0.0010
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0034 - val_acc: 0.0000e+00 - val_loss: 0.0153 - learning_rate: 0.0010
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0028 - val_acc: 0.0000e+00 - val_loss: 0.0167 - learning_rate: 0.0010
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0024 - val_acc: 0.0000e+00 - val_loss: 0.0173 - learning_rate: 0.0010
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0022 - val_acc: 0.0000e+00 - val_loss: 0.0176 - learning_rate: 0.0010
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 0.0020 - val_acc: 0.0000e+00 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0018 - val_acc: 0.0000e+00 - val_loss: 0.0189 - learning_rate: 0.0010
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0020 - val_acc: 0.0000e+00 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0018 - val_acc: 0.0000e+00 - val_loss: 0.0211 - learning_rate: 0.0010
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0026 - val_acc: 0.0000e+00 - val_loss: 0.0208 - learning_rate: 0.0010
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0020 - val_acc: 0.0000e+00 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0016 - val_acc: 0.0000e+00 - val_loss: 0.0192 - learning_rate: 0.0010
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0013 - val_acc: 0.0000e+00 - val_loss: 0.0201 - learning_rate: 0.0010
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0012 - val_acc: 0.0000e+00 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0011 - val_acc: 0.0000e+00 - val_loss: 0.0213 - learning_rate: 0.0010
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 0.0014 - val_acc: 0.0000e+00 - val_loss: 0.0207 - learning_rate: 0.0010
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 0.0011 - val_acc: 0.0000e+00 - val_loss: 0.0216 - learning_rate: 0.0010
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 0.0013 - val_acc: 0.0000e+00 - val_loss: 0.0215 - learning_rate: 0.0010
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 0.0012 - val_acc: 0.0000e+00 - val_loss: 0.0209 - learning_rate: 0.0010
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 9.2028e-04 - val_acc: 0.0000e+00 - val_loss: 0.0207 - learning_rate: 0.0010
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0049 - loss: 7.3785e-04 - val_acc: 0.0000e+00 - val_loss: 0.0219 - learning_rate: 0.0010
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0049 - loss: 8.2148e-04 - val_acc: 0.0000e+00 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 0.0012 - val_acc: 0.0000e+00 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 9.5878e-04 - val_acc: 0.0000e+00 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 7.9558e-04 - val_acc: 0.0000e+00 - val_loss: 0.0223 - learning_rate: 0.0010
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 6.2277e-04 - val_acc: 0.0000e+00 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.5350e-04 - val_acc: 0.0000e+00 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.6518e-04 - val_acc: 0.0000e+00 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.8021e-04 - val_acc: 0.0000e+00 - val_loss: 0.0227 - learning_rate: 0.0010
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 6.0083e-04 - val_acc: 0.0000e+00 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.7452e-04 - val_acc: 0.0000e+00 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.9479e-04 - val_acc: 0.0000e+00 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.3004e-04 - val_acc: 0.0000e+00 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.4754e-04 - val_acc: 0.0000e+00 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.9097e-04 - val_acc: 0.0000e+00 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.0871e-04 - val_acc: 0.0000e+00 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.4491e-04 - val_acc: 0.0000e+00 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.2184e-04 - val_acc: 0.0000e+00 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.8880e-04 - val_acc: 0.0000e+00 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.1545e-04 - val_acc: 0.0000e+00 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.9884e-04 - val_acc: 0.0000e+00 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.8885e-04 - val_acc: 0.0000e+00 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.3028e-04 - val_acc: 0.0000e+00 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 2.0946e-04 - val_acc: 0.0000e+00 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.1943e-04 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.1525e-04 - val_acc: 0.0000e+00 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.8550e-04 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.0539e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.4637e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.4750e-04 - val_acc: 0.0000e+00 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.5868e-04 - val_acc: 0.0000e+00 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.7229e-04 - val_acc: 0.0000e+00 - val_loss: 0.0238 - learning_rate: 0.0010
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.2264e-04 - val_acc: 0.0000e+00 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.7367e-04 - val_acc: 0.0000e+00 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.5552e-04 - val_acc: 0.0000e+00 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.3096e-04 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.0223e-04 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.0432e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.9573e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.7893e-04 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.7627e-04 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0049 - loss: 1.9908e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.5674e-04 - val_acc: 0.0000e+00 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.6316e-04 - val_acc: 0.0000e+00 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.0166e-04 - val_acc: 0.0000e+00 - val_loss: 0.0242 - learning_rate: 0.0010
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.1676e-04 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 8.4589e-05 - val_acc: 0.0000e+00 - val_loss: 0.0246 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 7.0730e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.7233e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.5738e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.2385e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 5.3099e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.5225e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.3378e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.3554e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.0879e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 4.1279e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 3.9560e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.8950e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.8574e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.7187e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 3.7469e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.8740e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.6409e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.5748e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.6032e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.5269e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.5464e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.4355e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.4664e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.3626e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.4113e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.2854e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.3185e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.3637e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.3219e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0049 - loss: 3.1976e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.1998e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.1734e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 3.3520e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.0932e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 3.1480e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.0333e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.0044e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.9204e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.1082e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.8947e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.8806e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.8500e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.9282e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.8731e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 3.1004e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.8302e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 2.7452e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.6700e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.6893e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.6718e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.6160e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.8986e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.7255e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5912e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.5671e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.5430e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5223e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4594e-05 - val_acc: 0.0000e+00 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4608e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4394e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4685e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4606e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5860e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4802e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.3046e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4248e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.6515e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5445e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.9548e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5342e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.5434e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.3736e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.4720e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 2.1003e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.1834e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.0940e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.1769e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - acc: 0.0049 - loss: 2.0913e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.1015e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.0410e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.9825e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - acc: 0.0049 - loss: 1.9756e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.9592e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.9450e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.0167e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8770e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8964e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8451e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8410e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8744e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - acc: 0.0049 - loss: 1.8567e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 2.1032e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.8458e-05 - val_acc: 0.0000e+00 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.7607e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.7402e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - acc: 0.0049 - loss: 1.7252e-05 - val_acc: 0.0000e+00 - val_loss: 0.0245 - learning_rate: 1.0000e-04

# %%
# Loss History

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('Model Loss for MOX with cnn_1d')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.legend(['Train', 'Test'], loc='upper right')
pyplot.savefig('MOX_cnn_1d.png', dpi=300)
pyplot.show()

# %%
y_test = test_set.iloc[timestamp:].values

cases = (test_set.values).reshape(-1, 1)
cases_scaled = sc.transform(cases)

# %%
# the model will predict the values on x_test
x_test = [] 
length = len(test_set)

for i in range(timestamp, length):
    x_test.append(cases_scaled[i-timestamp:i, 0])
    
x_test = np.array(x_test)
print (x_test.shape)
x_test = np.reshape(x_test, (x_test.shape[0], n_steps, 1))
# Out:
# (431, 108)

# %%
def RSE(y_true, y_predicted):
    """
    - y_true: Actual values
    - y_predicted: Predicted values
    """
    y_true = np.array(y_true)
    y_predicted = np.array(y_predicted)
    RSS = np.sum(np.square(y_true - y_predicted))

    rse = math.sqrt(RSS / (len(y_true) - 2))
    return rse

# %%
start = time.time()
y_pred = cnn_1d.predict(x_test)
#print(y_pred)
print ('compilation time : ', (time.time() - start)*1000.0)

predicted_value = sc.inverse_transform(y_pred)
#print(predicted_value)

# calculate Metric
mae = mean_absolute_error(predicted_value, y_test)
mse = mean_squared_error(predicted_value, y_test)
rmse = sqrt(mean_squared_error(predicted_value, y_test))
forecast_error = np.mean(np.subtract(predicted_value, y_test))
#https://www.investopedia.com/terms/r/residual-standard-deviation.asp
rsd = RSE(y_test, predicted_value)

#r2_value = r2_score(predicted_value, y_test,multioutput='variance_weighted')
r2_value = r2_score(predicted_value, y_test)
print('Test MAE: %.3f' % mae)
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
print('Test FE: %.3f' % forecast_error)
print('Test R2: %.3f' % r2_value)
print('Test RSD: %.3f' % rsd)

#print (predicted_value)

# plotting the results
fig, ax = pyplot.subplots()
pyplot.plot(y_test, color = 'blue', label = 'Actual Total Step(s)')
pyplot.plot(predicted_value, color = 'red', label = 'Predicted Total Step(s)')
#plt.title('Case Prediction - mul_layer_3 Model')
#plt.xlabel('Time')
#plt.ylabel('Total Case(s)')
ax.set_xlabel('Days')
ax.set_ylabel('Total Step(s)')
ax.set_title('Step Prediction for MOX')
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
pyplot.legend(loc='upper right')
pyplot.savefig('MOX_Cnn1d.png', dpi=300)
pyplot.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# compilation time :  108.06083679199219
# Test MAE: 413.104
# Test MSE: 2280551.750
# Test RMSE: 1510.150
# Test FE: 11.542
# Test R2: 0.924
# Test RSD: 1513.666

# %%
start = time.time()
#print(y_pred)

# load data
steps = df['steps'].values
#steps = df['Steps'].values
series=pd.Series(steps)

#AutoCorrelation Function
plot_acf(series)
pyplot.show()

#Partial autocorrelation function
#plot_pacf(series, lags=50)
plot_pacf(series, lags=14)
pyplot.show()

# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']

# split into train and test sets
X = dataframe.values
train_size = int(len(X) * 0.8)
train, test = X[1:train_size], X[train_size:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# persistence model on training set
train_pred = [x for x in train_X]

# calculate residuals
train_resid = [train_y[i]-train_pred[i] for i in range(len(train_pred))]

# model the training set residuals
window = 5
model = AutoReg(train_resid, lags=5)
model_fit = model.fit()
coef = model_fit.params

# walk forward over time steps in test
history = train_resid[len(train_resid)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()

for t in range(len(test_y)):
	# persistence
	yhat = test_X[t]
	error = test_y[t] - yhat
    
	# predict error
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	pred_error = coef[0]
	for d in range(window):
		pred_error += coef[d+1] * lag[window-d-1]
        
	# correct the prediction
	yhat = yhat + pred_error
	predictions.append(yhat)
	history.append(error)
	print('predicted=%f, expected=%f' % (yhat, test_y[t]))

#RSD
rsd = RSE(y_test, predicted_value)
print('Test RSD: %.3f' % rsd)
# error
rmse = sqrt(mean_squared_error(test_y, predictions))
print('Test RMSE: %.3f' % rmse)

forecast_error = np.mean(np.subtract(predicted_value, y_test))
print('Test fe: %.3f' % forecast_error)

r2_value = r2_score(predicted_value, y_test)
print('Test r2: %.3f' % r2_value)

# plot predicted error
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')
pyplot.title('Residual Error Minimization for MOX')
pyplot.ylabel('Total steps')
pyplot.xlabel('Days')
pyplot.legend(['Expected', 'Predicted'], loc='upper right')
pyplot.savefig('AR_REM_MOX.png', dpi=300)
pyplot.show()

print ('compilation time : ', (time.time() - start)*1000.0)
# Out:
# predicted=10254.228789, expected=7040.000000
# predicted=10030.939191, expected=1154.000000
# predicted=7121.809310, expected=7680.000000
# predicted=6022.561867, expected=2759.000000
# predicted=3659.240715, expected=6352.000000
# predicted=6965.669660, expected=7225.000000
# predicted=4751.050628, expected=7250.000000
# predicted=7324.350839, expected=10194.000000
# predicted=7708.244664, expected=7788.000000
# predicted=7313.292397, expected=661.000000
# predicted=4184.507636, expected=12339.000000
# predicted=9451.319699, expected=3723.000000
# predicted=5326.688009, expected=9307.000000
# predicted=9746.625515, expected=12002.000000
# predicted=7212.248192, expected=15266.000000
# predicted=13598.214648, expected=14302.000000
# predicted=11430.739718, expected=16761.000000
# predicted=14210.499247, expected=6737.000000
# predicted=9495.804605, expected=16331.000000
# predicted=15508.955654, expected=14163.000000
# predicted=12948.753814, expected=14683.000000
# predicted=16076.311222, expected=15176.000000
# predicted=12676.116756, expected=5031.000000
# predicted=9694.272174, expected=7687.000000
# predicted=10320.792969, expected=11136.000000
# predicted=10676.495820, expected=13022.000000
# predicted=13270.987581, expected=15780.000000
# predicted=12528.327383, expected=9261.000000
# predicted=9566.112691, expected=9688.000000
# predicted=10739.481628, expected=9882.000000
# predicted=10218.586107, expected=15496.000000
# predicted=14637.760422, expected=10064.000000
# predicted=10406.403650, expected=9211.000000
# predicted=10392.783613, expected=14958.000000
# predicted=12176.427968, expected=3151.000000
# predicted=7963.341858, expected=3161.000000
# predicted=7004.885120, expected=3151.000000
# predicted=4161.378849, expected=13640.000000
# predicted=12227.612409, expected=14364.000000
# predicted=10302.451356, expected=6573.000000
# predicted=7443.652615, expected=16676.000000
# predicted=11726.840103, expected=8903.000000
# predicted=9645.668009, expected=8487.000000
# predicted=11807.628991, expected=12401.000000
# predicted=9757.621829, expected=15279.000000
# predicted=14498.762476, expected=15338.000000
# predicted=13682.943160, expected=11536.000000
# predicted=11408.961778, expected=9597.000000
# predicted=10959.542484, expected=7760.000000
# predicted=10139.073457, expected=10740.000000
# predicted=11722.730107, expected=8911.000000
# predicted=9740.013078, expected=10021.000000
# predicted=10189.979213, expected=9129.000000
# predicted=8677.987983, expected=2661.000000
# predicted=6193.768784, expected=16345.000000
# predicted=12554.097876, expected=9466.000000
# predicted=8919.046009, expected=8137.000000
# predicted=10343.546298, expected=6947.000000
# predicted=5658.548190, expected=9317.000000
# predicted=10606.024830, expected=14922.000000
# predicted=12346.239474, expected=9668.000000
# predicted=9724.970928, expected=8891.000000
# predicted=9360.119979, expected=13458.000000
# predicted=11067.964738, expected=12250.000000
# predicted=12573.580427, expected=12612.000000
# predicted=12309.762532, expected=10886.000000
# predicted=10443.512785, expected=13216.000000
# predicted=12946.124355, expected=14652.000000
# predicted=13399.878338, expected=15114.000000
# predicted=14307.854461, expected=5025.000000
# predicted=8510.180865, expected=7671.000000
# predicted=9838.988677, expected=11031.000000
# predicted=10577.851771, expected=12954.000000
# predicted=13207.680701, expected=15714.000000
# predicted=12468.271667, expected=9217.000000
# predicted=9530.389947, expected=9659.000000
# predicted=10686.337920, expected=9869.000000
# predicted=10185.070567, expected=15447.000000
# predicted=14588.630448, expected=10048.000000
# predicted=10380.356968, expected=9148.000000
# predicted=10341.153673, expected=14910.000000
# predicted=12143.069934, expected=3123.000000
# predicted=7922.274978, expected=13609.000000
# predicted=12624.098674, expected=13611.000000
# predicted=10429.515258, expected=12286.000000
# predicted=13873.602974, expected=3688.000000
# predicted=5404.165301, expected=9274.000000
# predicted=10035.730974, expected=11934.000000
# predicted=10890.209144, expected=15236.000000
# predicted=14058.418164, expected=14244.000000
# predicted=11377.322630, expected=16732.000000
# predicted=14181.173812, expected=6711.000000
# predicted=9452.993943, expected=16153.000000
# predicted=15400.275467, expected=14069.000000
# predicted=12868.091466, expected=14324.000000
# predicted=15839.301713, expected=6233.000000
# predicted=7824.168967, expected=10796.000000
# predicted=12143.042132, expected=10266.000000
# predicted=10576.380824, expected=9334.000000
# predicted=11402.067769, expected=9496.000000
# predicted=8823.816448, expected=6570.000000
# predicted=8062.595251, expected=12279.000000
# predicted=11087.048682, expected=15766.000000
# predicted=12550.359682, expected=4826.000000
# predicted=8051.167458, expected=6943.000000
# predicted=7875.629382, expected=16359.000000
# predicted=12425.456228, expected=5977.000000
# predicted=9757.958116, expected=11671.000000
# Test RSD: 1513.666
# Test RMSE: 4481.642
# Test fe: 11.542
# Test r2: 0.924
# compilation time :  171.84996604919434
